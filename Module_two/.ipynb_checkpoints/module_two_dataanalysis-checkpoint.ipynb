# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from matplotlib import rcParams

# %%
# load all worksheets into the notebook
transactions_df = pd.read_excel("KPMG_data_module_two.xlsx",sheet_name="Transactions",skiprows=[0])
newCustomerList_df = pd.read_excel("KPMG_data_module_two.xlsx",sheet_name="NewCustomerList",skiprows=[0])
customerDemographic_df = pd.read_excel("KPMG_data_module_two.xlsx",sheet_name="CustomerDemographic",skiprows=[0])
customerAddress_df = pd.read_excel("KPMG_data_module_two.xlsx",sheet_name="CustomerAddress",skiprows=[0])

# %%
# so we can view all the columns 
# didn't do rows because my computer sucks
pd.set_option('display.max_columns',None)

# %%
transactions_df.shape
# Out:
# (20000, 13)

# %%
newCustomerList_df.shape
# Out:
# (1000, 23)

# %%
customerDemographic_df.shape
# Out:
# (4000, 13)

# %%
customerAddress_df.shape
# Out:
# (3999, 6)

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
customerDemographic_df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
transactions_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
# merge dataframes on the customer id
customerdemo_transaction_df = pd.merge(transactions_df,customerDemographic_df,how="inner",on='customer_id')

# %%
customerdemo_transaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19997 entries, 0 to 19996
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       19997 non-null  int64
#  1   product_id                           19997 non-null  int64
#  2   customer_id                          19997 non-null  int64
#  3   transaction_date                     19997 non-null  datetime64[ns]
#  4   online_order                         19637 non-null  float64
#  5   order_status                         19997 non-null  object
#  6   brand                                19800 non-null  object
#  7   product_line                         19800 non-null  object
#  8   product_class                        19800 non-null  object
#  9   product_size                         19800 non-null  object
#  10  list_price                           19997 non-null  float64
# ...

# %%
# sort by transaction date to find out the last transaction date for this dataset
customerdemo_transaction_df.sort_values(by='transaction_date',ascending=False)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 4439              748          80         2865       2017-12-30           1.0
# 11869           13575          98         2396       2017-12-30           0.0
# 368              3938          95          993       2017-12-30           0.0
# 4297            19907          41         1721       2017-12-30           0.0
# 18636           13670          73         2165       2017-12-30           0.0
# ...               ...         ...          ...              ...           ...
# 1012            11676          96         1229       2017-01-01           0.0
# 1979            16575          19         1745       2017-01-01           0.0
# 11986            9363          62          871       2017-01-01           0.0
# 11935           11314           4         2068       2017-01-01           1.0
# 19080            8479          50         1099       2017-01-01           1.0
#
# ...

# %%
# last date of transactions
last_date = customerdemo_transaction_df['transaction_date'].max()

# %%
# find out how recent a customer purchased a product
customerdemo_transaction_df['recency_days']  = last_date - customerdemo_transaction_df['transaction_date']

# %%
# change datatype from datetime to string for splitting (next line)
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].astype("string")

# %%
# split so that we only take the first value
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].apply(lambda x: x.split(" ")[0])

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date first_name  last_name  \
# ...

# %%
# change datatype from datetime to float for calculations
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].astype("float")

# %%
# create a column calculating profit by subtracting cost from price
customerdemo_transaction_df['profit'] = customerdemo_transaction_df['list_price'] - customerdemo_transaction_df['standard_cost']

# %%
customerdemo_transaction_df.groupby(by='customer_id').sum()
# Out:
#              transaction_id  product_id  online_order  list_price  \
# customer_id
# 1                    126342         376           6.0     9084.45
# 2                     25415         112           1.0     4149.07
# 3                    110741         483           1.0     9888.23
# 4                     27089         157           1.0     1047.72
# 5                     47818         289           2.0     5903.20
# ...                     ...         ...           ...         ...
# 3496                  41277         123           3.0     4725.38
# 3497                  25695          97           2.0     3744.07
# 3498                  55965         433           5.0     5177.06
# 3499                  48099         299           4.0     7673.48
# 3500                  60456         240           2.0     4922.41
#
#              standard_cost  product_first_sold_date  \
# customer_id
# 1                  6066.36                 410455.0
# ...

# %%
# create a count of products purchases column
count_productid = customerdemo_transaction_df.groupby(by='customer_id').count()['product_id']

# %%
# create a column for the most recent time the customer purchased from Sprocket
min_transaction_days = customerdemo_transaction_df.groupby(by='customer_id')['recency_days'].min()

# %%
# find out sum of profit from each customer
sum_profit = customerdemo_transaction_df.groupby(by='customer_id').sum()['profit']

# %%
# create a customer dataframe
customer_df = pd.DataFrame({
    "min_recency":min_transaction_days,
    "product_count":count_productid,
    "sum_profit": sum_profit
})

# %%
customer_df.head()
# Out:
#              min_recency  product_count  sum_profit
# customer_id
# 1                    7.0             11     3018.09
# 2                  128.0              3     2226.26
# 3                  102.0              8     3362.81
# 4                  195.0              2      220.57
# 5                   16.0              6     2394.94

# %% [markdown]
# ### RFM Metrics
#
# * recency: time since last order or last engaged with the product
# * Total number of transactions or average time between transactions/engaged visits
# * total or average transactions value

# %%
# finding IQR for recency
Q1_recency = customer_df['min_recency'].quantile(0.25)
median_recency = customer_df['min_recency'].quantile(0.5)
Q3_recency = customer_df['min_recency'].quantile(0.75)
IQR_recency = Q3_recency - Q1_recency
print(Q1_recency)
print(median_recency)
print(Q3_recency)
print(IQR_recency)
# Out:
# 17.0
# 44.0
# 85.0
# 68.0

# %%
# finding IQR for products purchased
Q1_products = customer_df['product_count'].quantile(0.25)
median_products = customer_df['product_count'].quantile(0.5)
Q3_products = customer_df['product_count'].quantile(0.75)
IQR_products = Q3_products - Q1_products
print(Q1_products)
print(median_products)
print(Q3_products)
print(IQR_products)
# Out:
# 4.0
# 6.0
# 7.0
# 3.0

# %%
# finding IQR for sum of profit
Q1_profits = customer_df['sum_profit'].quantile(0.25)
median_products = customer_df['sum_profit'].quantile(0.5)
Q3_profits = customer_df['sum_profit'].quantile(0.75)
IQR_profits = Q3_profits - Q1_profits
print(Q1_profits)
print(median_products)
print(Q3_profits)
print(IQR_profits)
# Out:
# 1841.73
# 2862.330000000001
# 4183.81
# 2342.0800000000004

# %%
# recency_score list
recency_list = []
for a in customer_df['min_recency']:
    if a <= 17:
        recency_list.append(4)
    elif a > 17 and a <= 44:
        recency_list.append(3)
    elif a > 44 and a <= 85:
        recency_list.append(2)
    else:
        recency_list.append(1)

# %%
recency_list[:5]
# Out:
# [4, 1, 1, 1, 4]

# %%
# product_score list
product_list = []
for a in customer_df['product_count']:
    if a <= 4:
        product_list.append(1)
    elif a > 4 and a <= 6:
        product_list.append(2)
    elif a > 6 and a <= 7:
        product_list.append(3)
    else:
        product_list.append(4)

# %%
product_list[:5]
# Out:
# [4, 1, 4, 1, 2]

# %%
# product_score list
profit_list = []
for a in customer_df['sum_profit']:
    if a <= 1841.73:
        profit_list.append(1)
    elif a > 1841.73 and a <= 2862.33:
        profit_list.append(2)
    elif a > 2862.33 and a <= 4183.81:
        profit_list.append(3)
    else:
        profit_list.append(4)

# %%
customer_df.head()
# Out:
#              min_recency  product_count  sum_profit
# customer_id
# 1                    7.0             11     3018.09
# 2                  128.0              3     2226.26
# 3                  102.0              8     3362.81
# 4                  195.0              2      220.57
# 5                   16.0              6     2394.94

# %%
# insert recency score to the second column
customer_df.insert(1, "recency_score", recency_list)

# %%
customer_df.insert(3, "product_score", product_list)

# %%
customer_df['profit_score'] = profit_list

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score
# customer_id
# 1               3018.09             3
# 2               2226.26             2
# 3               3362.81             3
# 4                220.57             1
# 5               2394.94             2

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3493 entries, 1 to 3500
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   min_recency    3493 non-null   float64
#  1   recency_score  3493 non-null   int64
#  2   product_count  3493 non-null   int64
#  3   product_score  3493 non-null   int64
#  4   sum_profit     3493 non-null   float64
#  5   profit_score   3493 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 191.0 KB

# %%
",".join(map(str,customer_df[['recency_score','product_score',"profit_score"]].values.tolist()[0])).replace(",","")
# Out:
# '443'

# %%
RFM_score = []
for i in range(customer_df.shape[0]):    
    rfm_item = customer_df[['recency_score','product_score',"profit_score"]].values.tolist()[i]    
    RFM_score.append(",".join(map(str,rfm_item)).replace(",",""))

# %%
customer_df['RFM_score'] = RFM_score

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score RFM_score
# customer_id
# 1               3018.09             3       443
# 2               2226.26             2       112
# 3               3362.81             3       143
# 4                220.57             1       111
# 5               2394.94             2       422

# %%
customer_df['RFM_score'] = customer_df['RFM_score'].astype("float")

# %%
# create IQR for the RFM score
Q1_rfm = customer_df['RFM_score'].quantile(0.25)
median_rfm = customer_df['RFM_score'].quantile(0.5)
Q3_rfm = customer_df['RFM_score'].quantile(0.75)
print(Q1_rfm)
print(median_rfm)
print(Q3_rfm)
# Out:
# 211.0
# 311.0
# 411.0

# %%
customer_title = []
for j in customer_df['RFM_score']:
    if j <= 211:
        customer_title.append("Bronze")
    elif j >211 and j <=311:
        customer_title.append("Silver")
    elif j >311 and j <= 411:
        customer_title.append("Gold")
    else:
        customer_title.append("Platinum")

# %%
customer_df['customer_title'] = customer_title

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score  RFM_score customer_title
# customer_id
# 1               3018.09             3      443.0       Platinum
# 2               2226.26             2      112.0         Bronze
# 3               3362.81             3      143.0         Bronze
# 4                220.57             1      111.0         Bronze
# 5               2394.94             2      422.0       Platinum

# %%
customertitle_grouped_df = customer_df.groupby(by='customer_title').count().sort_values(by='min_recency')
customertitle_grouped_df
# Out:
#                 min_recency  recency_score  product_count  product_score  \
# customer_title
# Platinum                792            792            792            792
# Silver                  813            813            813            813
# Gold                    878            878            878            878
# Bronze                 1010           1010           1010           1010
#
#                 sum_profit  profit_score  RFM_score  customer_age  \
# customer_title
# Platinum               792           792        792           761
# Silver                 813           813        813           801
# Gold                   878           878        878           863
# Bronze                1010          1010       1010           991
#
#                 customer_age_group
# customer_title
# Platinum                       761
# Silver                         801
# Gold                           863
# Bronze                         991

# %%
top_1000_target_df = customer_df.sort_values(by='RFM_score', ascending=False).head(1000)[['RFM_score',"customer_title", "customer_age_group"]]

# %%
top_1000_target_df
# Out:
#              RFM_score customer_title customer_age_group
# customer_id
# 1460             444.0       Platinum              40-49
# 725              444.0       Platinum              50-59
# 2130             444.0       Platinum              20-29
# 2992             444.0       Platinum              40-49
# 753              444.0       Platinum              40-49
# ...                ...            ...                ...
# 139              344.0           Gold              50-59
# 760              344.0           Gold              30-39
# 2986             344.0           Gold              30-39
# 2985             344.0           Gold              30-39
# 765              344.0           Gold              30-39
#
# [1000 rows x 3 columns]

# %%
reorder_list = ['Platinum', 'Gold','Silver','Bronze']
customer_to_target_summarydf = pd.DataFrame(customertitle_grouped_df.reindex(reorder_list)['min_recency'])\
                                .rename(columns={"min_recency":"count"})

# %%
customer_to_target_summarydf
# Out:
#                 count
# customer_title
# Platinum          792
# Gold              878
# Silver            813
# Bronze           1010

# %%
customer_title_descriptions = ["bought more often and spent the most",
                              "bought relatively often and spent large amount of money",
                              "average purchase frequency and average spending habits",
                              "very low recency, frequency and money spent"]

# %%
customer_to_target_summarydf.insert(0, 
                                    "title_description", 
                                    customer_title_descriptions)

# %%
customer_to_target_summarydf
# Out:
#                                                 title_description  count
# customer_title
# Platinum                     bought more often and spent the most    792
# Gold            bought relatively often and spent large amount...    878
# Silver          average purchase frequency and average spendin...    813
# Bronze                very low recency, frequency and money spent   1010

# %%
sns.set(style="whitegrid")
# create the bar chart
ax = sns.barplot(x=customertitle_grouped_df.index, y= customertitle_grouped_df['RFM_score'])
# set figsize
sns.set(rc={"figure.figsize":(20,10)})
# set plot title
ax.set_title("Customer Classes Determined With RFM Analysis", fontsize=24)
# set x axis label
ax.set_xlabel("Customer Classes", fontsize=18)
# set y axis label
ax.set_ylabel("RFM Score",fontsize=18)
# set tick font size
ax.tick_params(labelsize=15)


# save figure to the "ppt_graphs" folder
plt.savefig("ppt_graphs/customer_classes_with_RFM.png")

# %%
customer_df['customer_title'].unique()
# Out:
# array(['Platinum', 'Bronze', 'Silver', 'Gold'], dtype=object)

# %%
# recency vs monetary (profit)

sns.set(style='whitegrid')
# graph scatterplot
ax = sns.scatterplot(x='min_recency',y='sum_profit',data=customer_df,hue='customer_title')
# set figsize
sns.set(rc={"figure.figsize":(25,13)})
# set plot title
ax.set_title("Recency vs Monetary With RFM Analysis", fontsize=24)
# set x axis label
ax.set_xlabel("Recency (Days)", fontsize=18)
# set y axis label
ax.set_ylabel("Monetary (Profit Values)",fontsize=18)
# set tick font size
ax.tick_params(labelsize=15)
# set legend title,location and fontsizes
plt.legend(title='Customer Classes',
           loc='upper right',
           fontsize=18,
           title_fontsize=23)



# save figure to the "ppt_graphs" folder
plt.savefig("ppt_graphs/recency_vs_profits_with_RFM.png")

# %%
# recency against frequency
sns.set(style='whitegrid')
rf = sns.lmplot(x='min_recency', 
                y='product_count',
                data=customer_df,
                hue="customer_title",
                fit_reg=False,
                height=11,
                # width is calculated by: aspect*height
                aspect=22/11,
                legend_out=False)

rf.axes[0,0].set_xlabel("Recency (Days)",fontsize=18)
rf.axes[0,0].set_ylabel("Frequency of Purchase",fontsize=18)
rf.axes[0,0].set_title("Recency vs Frequency RFM Analysis", fontsize=24)

# set tick font size
rf.axes[0,0].tick_params(labelsize=15)

# set legend title,location and fontsizes
plt.legend(title='Customer Classes',
           loc='upper right',
           fontsize=18,
           title_fontsize=23)


# rf.xlabel("Recency",fontsize=18)
# rf.ylabel("Frequency",fontsize=18)
# rf.title("Recency vs Frequency RFM Analysis")
plt.tight_layout()
# save figure to the "ppt_graphs" folder
plt.savefig("ppt_graphs/recency_vs_frequency_with_RFM.png")

# %%
# Frequency vs Monetary
sns.set(style='whitegrid')
rf = sns.lmplot(x='product_count', 
                y='sum_profit',
                data=customer_df,
                hue="customer_title",
                fit_reg=False,
                height=11,
                # width is calculated by: aspect*height
                aspect=22/11,
                legend_out=False)

rf.axes[0,0].set_xlabel("Frequency of Purchase",fontsize=18)
rf.axes[0,0].set_ylabel("Monetary (Profit Values)",fontsize=18)
rf.axes[0,0].set_title("Frequency vs Monetary RFM Analysis", fontsize=24)

# set tick font size
rf.axes[0,0].tick_params(labelsize=15)

# set legend title,location and fontsizes
plt.legend(title='Customer Classes',
           loc='best',
           fontsize=18,
           title_fontsize=23)


# rf.xlabel("Recency",fontsize=18)
# rf.ylabel("Frequency",fontsize=18)
# rf.title("Recency vs Frequency RFM Analysis")
plt.tight_layout()
# save figure to the "ppt_graphs" folder
plt.savefig("ppt_graphs/frequency_vs_monetary_with_RFM.png")

# %% [markdown]
# ## Age group analysis

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date first_name  last_name  \
# ...

# %%
customerdemo_transaction_df['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
customer_age = 2017 - customerdemo_transaction_df['DOB'].dt.year

# %%
customerdemo_transaction_df['customer_age'] = customer_age

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date first_name  last_name  \
# ...

# %%
customerdemo_transaction_df['customer_age'].sort_values(ascending=False)
# Out:
# 5904     174.0
# 5903     174.0
# 5910     174.0
# 5902     174.0
# 5909     174.0
#          ...
# 19488      NaN
# 19489      NaN
# 19490      NaN
# 19914      NaN
# 19915      NaN
# Name: customer_age, Length: 19997, dtype: float64

# %%
customerdemo_transaction_df.describe()['customer_age']
# Out:
# count    19551.000000
# mean        39.922817
# std         12.929370
# min         15.000000
# 25%         30.000000
# 50%         40.000000
# 75%         49.000000
# max        174.000000
# Name: customer_age, dtype: float64

# %%
# drop the customer who has the wrong DOB 
customerdemo_transaction_df = customerdemo_transaction_df.loc[customerdemo_transaction_df['customer_id']!=34]

# %%
customerdemo_transaction_df.describe()['customer_age']
# Out:
# count    19542.000000
# mean        39.861068
# std         12.608024
# min         15.000000
# 25%         30.000000
# 50%         40.000000
# 75%         49.000000
# max         86.000000
# Name: customer_age, dtype: float64

# %%
customerdemo_transaction_df.groupby(by='customer_id')['customer_age'].max()
# Out:
# customer_id
# 1       64.0
# 2       37.0
# 3       63.0
# 4       56.0
# 5       40.0
#         ...
# 3496    31.0
# 3497    31.0
# 3498    22.0
# 3499    38.0
# 3500    50.0
# Name: customer_age, Length: 3492, dtype: float64

# %%
customer_df['customer_age'] = customerdemo_transaction_df.groupby(by='customer_id')['customer_age'].max()

# %%
customer_df
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
# ...                  ...            ...            ...            ...
# 3496               256.0              1              4              1
# 3497                52.0              2              3              1
# 3498               127.0              1              6              2
# 3499                51.0              2              7              3
# 3500               144.0              1              6              2
#
#              sum_profit  profit_score  RFM_score customer_title  customer_age
# customer_id
# ...

# %%
bins = [customer_df['customer_age'].min(),\
        19,29,39,49,59,69,79,customer_df['customer_age'].max()]
labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
customer_age_groups = pd.cut(customer_df['customer_age'],bins,labels=labels,include_lowest=True)

# %%
customer_df['customer_age_group'] = customer_age_groups

# %%
customer_df.head(3)
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
#
#              sum_profit  profit_score  RFM_score customer_title  customer_age  \
# customer_id
# 1               3018.09             3      443.0       Platinum          64.0
# 2               2226.26             2      112.0         Bronze          37.0
# 3               3362.81             3      143.0         Bronze          63.0
#
#             customer_age_group
# customer_id
# 1                        60-69
# 2                        30-39
# 3                        60-69

# %%
customer_df.groupby(by="customer_age_group").count()
# Out:
#                     min_recency  recency_score  product_count  product_score  \
# customer_age_group
# 10-19                       196            196            196            196
# 20-29                       607            607            607            607
# 30-39                       825            825            825            825
# 40-49                       952            952            952            952
# 50-59                       601            601            601            601
# 60-69                       230            230            230            230
# 70-79                         3              3              3              3
# 80+                           2              2              2              2
#
#                     sum_profit  profit_score  RFM_score  customer_title  \
# customer_age_group
# 10-19                      196           196        196             196
# 20-29                      607           607        607             607
# ...

# %%
age_group_demographic = customer_df['customer_age_group'].value_counts().sort_index()

# %%
age_group_demographic
# Out:
# 10-19    196
# 20-29    607
# 30-39    825
# 40-49    952
# 50-59    601
# 60-69    230
# 70-79      3
# 80+        2
# Name: customer_age_group, dtype: int64

# %%
ax = sns.barplot(x = age_group_demographic.index, y= age_group_demographic)
ax.set_title("Customer Age Groups", fontsize=20)
ax.set_xlabel("Age Groups", fontsize=15)
ax.set_ylabel("Count",fontsize=15)
ax.tick_params(labelsize=12)
rcParams['figure.figsize'] = 20,10
plt.savefig("ppt_graphs/customer_age_groups.png")

# %% [markdown]
# find new customer demographics

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
# create a column for customer age
new_customer_age = 2017 - newCustomerList_df['DOB'].dt.year

# %%
newCustomerList_df['customer_age'] = new_customer_age

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
newCustomerList_df['customer_age'].describe()
# Out:
# count    983.000000
# mean      46.206511
# std       17.074268
# min       15.000000
# 25%       34.000000
# 50%       45.000000
# 75%       60.000000
# max       79.000000
# Name: customer_age, dtype: float64

# %%
new_customer_bins = [newCustomerList_df['customer_age'].min(),\
                    19,29,39,49,59,69,79]

new_customer_labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79"]

# %%
new_customer_age_groups = pd.cut(newCustomerList_df['customer_age'],
                                bins = new_customer_bins,
                                labels=new_customer_labels,
                                include_lowest=True)

# %%
new_customer_age_groups
# Out:
# 0      60-69
# 1      40-49
# 2      40-49
# 3      30-39
# 4      50-59
#        ...
# 995    50-59
# 996    10-19
# 997    60-69
# 998    60-69
# 999    60-69
# Name: customer_age, Length: 1000, dtype: category
# Categories (7, object): [10-19 < 20-29 < 30-39 < 40-49 < 50-59 < 60-69 < 70-79]

# %%
newCustomerList_df['customer_age_group'] = new_customer_age_groups

# %%
newCustomerList_df.loc[newCustomerList_df['customer_age'] == 79]
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 18      Odilia       Quick  Female                                   65
# 191   Franklin      Wohler    Male                                   55
# 265     Alleen       Eaken  Female                                   56
# 406     Kippar  Brimilcome    Male                                   21
# 414        Wyn       Meach    Male                                   37
# 585    Letizia       Poore  Female                                   27
# 689    Willard      Booton    Male                                   69
# 769     Andrea      Pendle  Female                                   86
# 797    Anthony     Morison    Male                                    7
# 885  Zachariah  Meininking    Male                                   40
# 977    Beverly     Domnick  Female                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
# group by age
new_age_group_demographic = newCustomerList_df['customer_age_group'].value_counts().sort_index()

# %%
new_age_group_demographic
# Out:
# 10-19     56
# 20-29    154
# 30-39    137
# 40-49    207
# 50-59    177
# 60-69    153
# 70-79     99
# Name: customer_age_group, dtype: int64

# %%
from matplotlib import rcParams

# %%
sns.set(style="whitegrid")
ax1 = sns.barplot(x=new_age_group_demographic.index, 
                  y=new_age_group_demographic)

ax1.set_title("New Customer Age Groups", fontsize=25)
ax1.set_xlabel("Age Groups", fontsize=18)
ax1.set_ylabel("Count",fontsize=18)
ax1.tick_params(labelsize=15)
rcParams['figure.figsize'] = 20,10

# set label on bars
for index, row in pd.DataFrame(new_age_group_demographic).reset_index().iterrows():
    ax1.text(row.name,
           row.customer_age_group + 3, 
           row.customer_age_group, 
           color='black', 
           ha="center",
           fontsize=15)
    
plt.savefig("ppt_graphs/new_customer_age_groups.png")

# %% [markdown]
# ## Wealth Segment By Age Analysis (New vs Old Customer)
# #### New Customers

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
newCustomerList_df[['wealth_segment','customer_age_group']].head()
# Out:
#       wealth_segment customer_age_group
# 0      Mass Customer              60-69
# 1      Mass Customer              40-49
# 2  Affluent Customer              40-49
# 3  Affluent Customer              30-39
# 4  Affluent Customer              50-59

# %%
newCustomerList_df
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
wealth_age_group_df = newCustomerList_df.groupby(['wealth_segment','customer_age_group']).size().reset_index()
wealth_age_group_df
# Out:
#        wealth_segment customer_age_group    0
# 0   Affluent Customer              10-19   17
# 1   Affluent Customer              20-29   39
# 2   Affluent Customer              30-39   30
# 3   Affluent Customer              40-49   50
# 4   Affluent Customer              50-59   40
# 5   Affluent Customer              60-69   40
# 6   Affluent Customer              70-79   19
# 7      High Net Worth              10-19   12
# 8      High Net Worth              20-29   43
# 9      High Net Worth              30-39   39
# 10     High Net Worth              40-49   45
# 11     High Net Worth              50-59   49
# 12     High Net Worth              60-69   36
# 13     High Net Worth              70-79   25
# 14      Mass Customer              10-19   27
# 15      Mass Customer              20-29   72
# 16      Mass Customer              30-39   68
# 17      Mass Customer              40-49  112
# 18      Mass Customer              50-59   88
# ...

# %%
wealth_age_group_df.rename(columns={0:"count"},inplace=True)

# %%
affluent_customer_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="Affluent Customer"]
highnetworth_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="High Net Worth"]
mass_customer_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="Mass Customer"]

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
sns.set(style="whitegrid")
g = sns.barplot(x="customer_age_group",
               y="count",
               hue="wealth_segment",
               data = wealth_age_group_df)
# set figure size
sns.set(rc={"figure.figsize":(20,10)})

g.set_title("New Customers Wealth Segment by Age", fontsize=25)
g.set_xlabel("Age Groups", fontsize=18)
g.set_ylabel("Count",fontsize=18)

# set tick fontsize
g.tick_params(labelsize=15)
# set legend fontsize
plt.legend(fontsize=18,title_fontsize=23)


plt.savefig("ppt_graphs/new_wealth_segment_by_age.png")

# %%
wealth_age_group_df['customer_age_group']
# Out:
# 0     10-19
# 1     20-29
# 2     30-39
# 3     40-49
# 4     50-59
# 5     60-69
# 6     70-79
# 7     10-19
# 8     20-29
# 9     30-39
# 10    40-49
# 11    50-59
# 12    60-69
# 13    70-79
# 14    10-19
# 15    20-29
# 16    30-39
# 17    40-49
# 18    50-59
# 19    60-69
# 20    70-79
# Name: customer_age_group, dtype: category
# Categories (7, object): [10-19 < 20-29 < 30-39 < 40-49 < 50-59 < 60-69 < 70-79]

# %% [markdown]
# #### Old Customers

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date first_name  last_name  \
# ...

# %%
customerdemo_transaction_df.shape
# Out:
# (19988, 28)

# %%
old_customer_agesegment_df = customerdemo_transaction_df.groupby(by=['customer_id','wealth_segment'],
                                                                   as_index=False).last()[['customer_id','wealth_segment','customer_age']]
old_customer_agesegment_df.head()
# Out:
#    customer_id     wealth_segment  customer_age
# 0            1      Mass Customer          64.0
# 1            2      Mass Customer          37.0
# 2            3      Mass Customer          63.0
# 3            4      Mass Customer          56.0
# 4            5  Affluent Customer          40.0

# %%
old_customer_bins = [old_customer_agesegment_df['customer_age'].min(),\
                    19,29,39,49,59,69,79,\
                     old_customer_agesegment_df['customer_age'].max()]
old_customer_labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
old_customer_age_groups = pd.cut(old_customer_agesegment_df['customer_age'],
                                bins = old_customer_bins,
                                labels = old_customer_labels,
                                include_lowest = True)

# %%
old_customer_age_groups[:5]
# Out:
# 0    60-69
# 1    30-39
# 2    60-69
# 3    50-59
# 4    40-49
# Name: customer_age, dtype: category
# Categories (8, object): [10-19 < 20-29 < 30-39 < 40-49 < 50-59 < 60-69 < 70-79 < 80+]

# %%
old_customer_agesegment_df['customer_age_group'] = old_customer_age_groups

# %%
old_customer_agesegment_df
# Out:
#       customer_id     wealth_segment  customer_age customer_age_group
# 0               1      Mass Customer          64.0              60-69
# 1               2      Mass Customer          37.0              30-39
# 2               3      Mass Customer          63.0              60-69
# 3               4      Mass Customer          56.0              50-59
# 4               5  Affluent Customer          40.0              40-49
# ...           ...                ...           ...                ...
# 3487         3496      Mass Customer          31.0              30-39
# 3488         3497  Affluent Customer          31.0              30-39
# 3489         3498      Mass Customer          22.0              20-29
# 3490         3499      Mass Customer          38.0              30-39
# 3491         3500  Affluent Customer          50.0              50-59
#
# [3492 rows x 4 columns]

# %%
# group by age groups:
old_age_group_demographic = old_customer_agesegment_df['customer_age_group'].value_counts().sort_index()

# %%
pd.DataFrame(old_age_group_demographic)
# Out:
#        customer_age_group
# 10-19                 196
# 20-29                 607
# 30-39                 825
# 40-49                 952
# 50-59                 601
# 60-69                 230
# 70-79                   3
# 80+                     2

# %%
sns.set(style="whitegrid")
ax1 = sns.barplot(x=old_age_group_demographic.index, y=old_age_group_demographic)

ax1.set_title("Old Customer Age Groups", fontsize=25)
ax1.set_xlabel("Age Groups", fontsize=18)
ax1.set_ylabel("Count",fontsize=18)
ax1.tick_params(labelsize=15)
rcParams['figure.figsize'] = 20,10

# set label on bars
for index, row in pd.DataFrame(old_age_group_demographic).reset_index().iterrows():
    ax1.text(row.name,
           row.customer_age_group + 3, 
           row.customer_age_group, 
           color='black', 
           ha="center",
           fontsize=15)


    
plt.savefig("ppt_graphs/old_customer_age_groups.png")

# %%
old_wealth_age_group_df = old_customer_agesegment_df.\
                            groupby(by=['wealth_segment','customer_age_group']).\
                            size().\
                            reset_index().\
                            rename(columns={0:"count"})

old_wealth_age_group_df.head(6)
# Out:
#       wealth_segment customer_age_group  count
# 0  Affluent Customer              10-19     50
# 1  Affluent Customer              20-29    149
# 2  Affluent Customer              30-39    193
# 3  Affluent Customer              40-49    234
# 4  Affluent Customer              50-59    157
# 5  Affluent Customer              60-69     52

# %%
sns.set(style="whitegrid")
g = sns.barplot(x="customer_age_group",
               y="count",
               hue="wealth_segment",
               data = old_wealth_age_group_df)
# g = sns.catplot(x="customer_age_group",
#                 y="count",
#                 hue="wealth_segment",
#                 data=wealth_age_group_df,
#                 kind="bar")
sns.set(rc={"figure.figsize":(20,10)})
g.set_title("Old Customers Wealth Segment by Age", fontsize=25)
g.set_xlabel("Age Groups", fontsize=18)
g.set_ylabel("Count",fontsize=18)
g.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)




plt.savefig("ppt_graphs/old_wealth_segment_by_age.png")

# %% [markdown]
# ## Job Industry Distribution (New vs Old Customer)
# #### New Customers

# %%
# job industry distribution
job_industry_category = newCustomerList_df['job_industry_category'].value_counts()
job_industry_category.plot.pie(y="job_industry_category",
                               autopct="%1.2f%%",
                               fontsize=17)

plt.title("New Customer Job Industry Category Distribution", fontsize=23)
plt.ylabel("")

plt.savefig("ppt_graphs/new_job_industry_category_distribution.png")

# %% [markdown]
# #### Old Customers

# %%
customerdemo_transaction_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19992           19854          68          130       2017-02-02           1.0
# 19993           17966          17         2789       2017-12-06           0.0
# 19994           18462          80         2789       2017-06-20           0.0
# 19995           17981          69         3446       2017-12-26           1.0
# 19996           18165          86         3446       2017-12-03           0.0
#
# ...

# %%
# job industry distribution
job_industry_category = customerdemo_transaction_df['job_industry_category'].value_counts()

job_industry_category.plot.pie(y="job_industry_category",
                               autopct="%1.2f%%",
                              fontsize=17)

plt.title("Old Customer Job Industry Category Distribution", fontsize=23)
plt.ylabel("")

plt.savefig("ppt_graphs/old_job_industry_category_distribution.png")

# %% [markdown]
# ## Bike related purchases for the past 3 years by gender

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
newCustomerList_df['past_3_years_bike_related_purchases'].sum()
# Out:
# 49836

# %%
newCustomerList_df.groupby(by='gender').sum()['past_3_years_bike_related_purchases']
# Out:
# gender
# Female    25212
# Male      23765
# U           859
# Name: past_3_years_bike_related_purchases, dtype: int64

# %%
# past 3 years purchases by gender
colors = ['lightskyblue','gold',"lightgreen"]

# define function that displays percentage and numeric value
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


new_past_three_years = newCustomerList_df.groupby(by='gender').sum()['past_3_years_bike_related_purchases']
new_past_three_years.plot.pie(y="past_3_years_bike_related_purchases",
                              autopct=make_autopct(new_past_three_years.values),
                              startangle=120,
                              colors=colors,
                             fontsize=17)
plt.title("new customer total bike related purchases for the past 3 years by gender".title(), fontsize=25)
plt.ylabel("")

plt.savefig("ppt_graphs/new_customer_bike_related_purchases_for_the_past_3_years_by_gender.png")

# %% [markdown]
# ## Car Ownership by State (New vs Old Customer)
# #### New Customers

# %%
newCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
newCustomerList_df[['state','owns_car',"first_name"]].sort_values(by='state')
# Out:
#     state owns_car first_name
# 999   NSW      Yes      Sylas
# 391   NSW       No      Tamar
# 719   NSW      Yes  Inglebert
# 389   NSW       No       Fara
# 720   NSW       No    Brendis
# ..    ...      ...        ...
# 352   VIC      Yes    Delinda
# 354   VIC      Yes  Giulietta
# 356   VIC      Yes      Brynn
# 359   VIC       No       Pace
# 796   VIC      Yes      Amara
#
# [1000 rows x 3 columns]

# %%
state_owncar_df = newCustomerList_df[['state','owns_car',"first_name"]].groupby(["state",'owns_car'],as_index=False).count()
state_owncar_df
# Out:
#   state owns_car  first_name
# 0   NSW       No         272
# 1   NSW      Yes         234
# 2   QLD       No         103
# 3   QLD      Yes         125
# 4   VIC       No         132
# 5   VIC      Yes         134

# %%
state_owncar_df.loc[state_owncar_df['state']=="NSW","first_name"].sum()
# Out:
# 506

# %%
state_owncar_df['first_name'][0]
# Out:
# 272

# %%
NSW_sum = state_owncar_df.loc[state_owncar_df['state']=="NSW","first_name"].sum()
QLD_sum = state_owncar_df.loc[state_owncar_df['state']=="QLD","first_name"].sum()
VIC_sum = state_owncar_df.loc[state_owncar_df['state']=="VIC","first_name"].sum()

# %%
car_ownership_percentage = []
for i in range(state_owncar_df.shape[0]):
    if state_owncar_df['state'][i] == "NSW":
        some_percentage = round((state_owncar_df['first_name'][i] / NSW_sum * 100),2)
        car_ownership_percentage.append(some_percentage)
    elif state_owncar_df['state'][i] == "QLD":
        some_percentage = round((state_owncar_df['first_name'][i] / QLD_sum * 100),2)
        car_ownership_percentage.append(some_percentage)
    else:
        some_percentage = round((state_owncar_df['first_name'][i] / VIC_sum * 100),2)
        car_ownership_percentage.append(some_percentage)

# %%
car_ownership_percentage
# Out:
# [53.75, 46.25, 45.18, 54.82, 49.62, 50.38]

# %%
state_owncar_df['percentage'] = car_ownership_percentage

# %%
state_owncar_df
# Out:
#   state owns_car  first_name  percentage
# 0   NSW       No         272       53.75
# 1   NSW      Yes         234       46.25
# 2   QLD       No         103       45.18
# 3   QLD      Yes         125       54.82
# 4   VIC       No         132       49.62
# 5   VIC      Yes         134       50.38

# %%
sns.set(style='whitegrid')
state_owncar_graph = sns.barplot(x="owns_car",
                                 y='first_name',
                                 data=state_owncar_df,
                                 hue='state')
sns.set(rc={"figure.figsize":(22,11)})
state_owncar_graph.set_title("number of car owners in each state for new customers".title(),fontsize=24)
state_owncar_graph.set_xlabel("Owns Car",fontsize=18)
state_owncar_graph.set_ylabel("Count",fontsize=18)
state_owncar_graph.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)

plt.savefig("ppt_graphs/new_customers_number_cars_own_per_state.png")

# %% [markdown]
# #### Old Customers

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date first_name  last_name  \
# ...

# %%
customerAddress_df.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
bins = [customerdemo_transaction_df['customer_age'].min(),\
        19,29,39,49,59,69,79,customerdemo_transaction_df['customer_age'].max()]
labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
customer_age_group = pd.cut(customerdemo_transaction_df['customer_age'],
                       bins=bins,
                       labels=labels,
                       include_lowest=True)

# %%
customerdemo_transaction_df['customer_age_group'] = customer_age_group
# Out:
# C:\Users\smartestpersonalive\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# get the state from the customerAddress worksheet
complete_old_customer_df = pd.merge(customerdemo_transaction_df, 
                                     customerAddress_df, 
                                     how="inner",
                                     on = "customer_id")

# %%
complete_old_customer_df['state'].unique()
# Out:
# array(['VIC', 'NSW', 'QLD', 'Victoria', 'New South Wales'], dtype=object)

# %%
# handle duplicate values (ie. VIC and Victoria are the same state)
complete_old_customer_df['state'] = complete_old_customer_df['state'].replace("Victoria","VIC")\
                                                            .replace("New South Wales", "NSW")

# %%
complete_old_customer_df[['state','owns_car','first_name']].sort_values(by='state')
# Out:
#       state owns_car first_name
# 9979    NSW       No      Dyann
# 15145   NSW       No      Arlan
# 15144   NSW       No      Arlan
# 15138   NSW       No     Morgun
# 15137   NSW       No  Elbertine
# ...     ...      ...        ...
# 15427   VIC      Yes       Bert
# 15426   VIC      Yes       Bert
# 7295    VIC       No     Mahmud
# 15451   VIC      Yes      Phebe
# 0       VIC      Yes    Kristos
#
# [19959 rows x 3 columns]

# %%
old_stateowncar_df = complete_old_customer_df[['state','owns_car','first_name']].groupby(['state','owns_car'],as_index=False).count()
old_stateowncar_df
# Out:
#   state owns_car  first_name
# 0   NSW       No        5201
# 1   NSW      Yes        5484
# 2   QLD       No        2120
# 3   QLD      Yes        2133
# 4   VIC       No        2596
# 5   VIC      Yes        2425

# %%
sns.set(style='whitegrid')
state_owncar_graph = sns.barplot(x="owns_car",
                                 y='first_name',
                                 data=old_stateowncar_df,
                                 hue='state')
sns.set(rc={"figure.figsize":(22,11)})
state_owncar_graph.set_title("number of car owners in each state for old customers".title(),fontsize=24)
state_owncar_graph.set_xlabel("Owns Car",fontsize=18)
state_owncar_graph.set_ylabel("Count",fontsize=18)
state_owncar_graph.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)

plt.savefig("ppt_graphs/old_customers_number_cars_own_per_state.png")

# %%
complete_old_customer_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19954           19854          68          130       2017-02-02           1.0
# 19955           17966          17         2789       2017-12-06           0.0
# 19956           18462          80         2789       2017-06-20           0.0
# 19957           17981          69         3446       2017-12-26           1.0
# 19958           18165          86         3446       2017-12-03           0.0
#
# ...

# %%
customer_title_column = pd.DataFrame(customer_df['customer_title'])

# %%
complete_old_customer_df = pd.merge(complete_old_customer_df,customer_title_column,how='inner',on='customer_id')

# %%
complete_old_customer_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19954           19854          68          130       2017-02-02           1.0
# 19955           17966          17         2789       2017-12-06           0.0
# 19956           18462          80         2789       2017-06-20           0.0
# 19957           17981          69         3446       2017-12-26           1.0
# 19958           18165          86         3446       2017-12-03           0.0
#
# ...

# %%
complete_old_customer_df.to_csv("C:/Users/smartestpersonalive/Documents/Github_files/KPMG-virtualinternship/Module_three/complete_old_customer_df2.csv",index=False)

# %%
# add a tenure column to the customer_df
tenure_column = pd.DataFrame(complete_old_customer_df.groupby(by='customer_id').last()['tenure'])

# %%
customer_df = pd.merge(customer_df,tenure_column,how='inner',on='customer_id')

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score  RFM_score customer_title  customer_age  \
# customer_id
# 1               3018.09             3      443.0       Platinum          64.0
# 2               2226.26             2      112.0         Bronze          37.0
# 3               3362.81             3      143.0         Bronze          63.0
# 4                220.57             1      111.0         Bronze          56.0
# 5               2394.94             2      422.0       Platinum          40.0
#
#             customer_age_group
# customer_id
# ...

# %%
customer_df.to_csv("C:/Users/smartestpersonalive/Documents/Github_files/KPMG-virtualinternship/Module_three/customer_df.csv")

# %%
# # create equal bins
# recency_bins = np.linspace(min(customer_df['min_recency']),max(customer_df['min_recency']),5)
# # set group names
# recency_groups = [1,2,3,4]

# pd.cut(customer_df['min_recency'],recency_bins,labels=recency_groups,include_lowest=True).unique()
# recency_bins
# Out:
# [1, 2, 3, 4]
# Categories (4, int64): [1 < 2 < 3 < 4]
